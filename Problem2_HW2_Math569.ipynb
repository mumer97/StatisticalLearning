# %%
import numpy as np
import plotly.graph_objects as go
from numpy.linalg import inv
from scipy.stats import chi2

n = 20
sigma = np.sqrt(0.5)

# prepare data
ones = np.ones(n)
x = np.random.uniform(0, 1, n)
x = np.sort(x)
x_square = np.square(x)
x_cubic = np.power(x, 3)

X = np.column_stack((ones, x, x_square, x_cubic))
X_T = X.transpose()

noise = np.random.normal(0, sigma, n)

Beta = np.array([1, 1, 2, 3])
y_theory = X @ Beta
y_realized = y_theory + noise

beta_hat = inv(X_T @ X) @ X_T @ y_realized
y_estimated = X @ beta_hat

# Approach A
var_beta_hat = inv(X_T @ X) * (sigma**2)
tmp = X @ var_beta_hat
tmp = tmp @ X_T
width = np.diag(tmp)
width = np.sqrt(width)
upperbound = y_estimated + 1.96 * width
lowerbound = y_estimated - 1.96 * width


# Approach B
U_T = np.linalg.cholesky(X_T @ X)
U = U_T.transpose()
U_inv = inv(U)

p = 0.95
df = 4
num = 100

region_arr = []

for i in range(num):
    a = np.random.normal(0, 1, df)
    a = U_inv @ a
    a_norm = np.linalg.norm(a, ord=2)

    r = sigma * np.sqrt(chi2.ppf(p, df))
    a = a * (r/a_norm)

    beta2 = Beta + a
    region = np.dot(X, beta2)
    region_arr.append(region)

# plot
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y_estimated, mode='lines+markers', name='estimated', line_color='#006400'))
fig.add_trace(go.Scatter(x=x, y=upperbound, mode='lines+markers', name='upper1', line_color='#FFFF00'))
fig.add_trace(go.Scatter(x=x, y=lowerbound, mode='lines+markers', name='lower1', line_color='#FFFF00'))

for i in range(num):
    fig.add_trace(go.Scatter(x=x, y=region_arr[i], mode='lines', line_color='#ADD8E6'))

fig.show()
# Out:
# <div>                            <div id="1d5fa40f-8e0c-419d-b0c1-f5ffd95b7c85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d5fa40f-8e0c-419d-b0c1-f5ffd95b7c85")) {                    Plotly.newPlot(                        "1d5fa40f-8e0c-419d-b0c1-f5ffd95b7c85",                        [{"line":{"color":"#006400"},"mode":"lines+markers","name":"estimated","x":[0.03695850922635613,0.03861490940017076,0.08388157682947295,0.19594381961526808,0.21153292591877426,0.23508279501836227,0.24896158435964721,0.3342021331167383,0.3896322601922214,0.4291422485300932,0.4729499894952611,0.5725025179396455,0.6162675935673094,0.6810702154448506,0.6985469323048078,0.7682950271621932,0.7780068569462728,0.8441467398059749,0.9160107889200625,0.9891282879945013],"y":
# ...
